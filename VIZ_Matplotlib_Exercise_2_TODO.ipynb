# %% [markdown]
# <a href="https://colab.research.google.com/github/immune-institute/viz-matplotlib-exercise-2-todo/blob/main/VIZ_Matplotlib_Exercise_2_TODO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Initial Setup**

# %% [markdown]
# Import matplotlib and pandas:

# %% [markdown]
# Import dataset from https://raw.githubusercontent.com/immune-institute/viz-datasets/main/company_sales.csv:

# %% [markdown]
# ##**Exercices**

# %% [markdown]
# ###**EXERCISE 1**:

# %% [markdown]
# Plot the graph below:

# %%
#CODE HERE

# %% [markdown]
# ###**EXERCISE 2**:

# %% [markdown]
# Plot the graph below:

# %%
#CODE HERE

# %% [markdown]
# ###**EXERCISE 3**:

# %% [markdown]
# Plot the graph below:

# %%
#CODE HERE
